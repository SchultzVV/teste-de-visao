# %%
# !curl -X POST -F "image=@/home/juannascimento/Projetos/teste-de-visao/src/img46_gray_noise.png" http://localhost:5000/questao1
# Out:
# {
#   "result": "..."
# }

# %%
# !curl -X POST -F "image=@/home/juannascimento/Projetos/teste-de-visao/src/img67.png" http://localhost:5000/questao2a
# Out:
# {
#   "result": "..."
# }
